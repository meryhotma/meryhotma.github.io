# %% [markdown]
# # Exploring the Data
#
# url: https://datasets.wri.org/datasets/global-power-plant-database?map=...%3D

# %%
# import dataset

import pandas as pd

df_pw = pd.read_csv("global_power_plant_database.csv", low_memory=False)

df_pw
# Out:
#       country country_long                                               name  \
# 0         AFG  Afghanistan       Kajaki Hydroelectric Power Plant Afghanistan
# 1         AFG  Afghanistan                                       Kandahar DOG
# 2         AFG  Afghanistan                                       Kandahar JOL
# 3         AFG  Afghanistan      Mahipar Hydroelectric Power Plant Afghanistan
# 4         AFG  Afghanistan   Naghlu Dam Hydroelectric Power Plant Afghanistan
# ...       ...          ...                                                ...
# 34931     ZMB       Zambia                                              Ndola
# 34932     ZMB       Zambia                                              Nkana
# 34933     ZMB       Zambia                                     Victoria Falls
# 34934     ZWE     Zimbabwe                   Hwange Coal Power Plant Zimbabwe
# 34935     ZWE     Zimbabwe  Kariba Dam South Hydroelectric Power Station Z...
#
# ...

# %%
indonesia = df_pw[
    (df_pw["primary_fuel"] == "Coal") & (df_pw["country_long"] == "Indonesia")
]


indonesia
# Out:
#       country country_long                               name   gppd_idnr  \
# 15641     IDN    Indonesia       Amamapare Port power station  WRI1075798
# 15643     IDN    Indonesia              Amurang power station  WRI1075799
# 15647     IDN    Indonesia        Banten Serang power station  WRI1075800
# 15648     IDN    Indonesia           Batu Hijau power station  WRI1075801
# 15653     IDN    Indonesia       Celukan Bawang power station  WRI1075802
# ...       ...          ...                                ...         ...
# 15786     IDN    Indonesia    Pekanbaru Tenayan power station  WRI1075813
# 15788     IDN    Indonesia        Perawang Mill power station  WRI1075814
# 15793     IDN    Indonesia  Purwakarta Indorama Power Station  WRI1075815
# 15803     IDN    Indonesia      Sulawesi Mining power station  WRI1075816
# 15808     IDN    Indonesia    Tanjung Awar-Awar power station  WRI1075817
#
#        capacity_mw  latitude  longitude primary_fuel other_fuel1 other_fuel2  \
# ...

# %%
indonesia_al = df_pw[df_pw["country_long"] == "Indonesia"]


indonesia_al
# Out:
#       country country_long                          name   gppd_idnr  \
# 15641     IDN    Indonesia  Amamapare Port power station  WRI1075798
# 15642     IDN    Indonesia                       Ampenan  WRI1000736
# 15643     IDN    Indonesia         Amurang power station  WRI1075799
# 15644     IDN    Indonesia                      Asahan I  WRI1000737
# 15645     IDN    Indonesia                        Bakaru  WRI1000738
# ...       ...          ...                           ...         ...
# 15814     IDN    Indonesia                Ubrug/saguling  WRI1001039
# 15815     IDN    Indonesia                 Ulubelu 1 & 2  WRI1001040
# 15816     IDN    Indonesia                  Wayang Windu  WRI1001044
# 15817     IDN    Indonesia              Wlingi - Brantas  WRI1001045
# 15818     IDN    Indonesia          Wonorejo - Pamekasan  WRI1001046
#
#        capacity_mw  latitude  longitude primary_fuel other_fuel1 other_fuel2  \
# ...

# %% [markdown]
# so, we have country names (country_long), longitude and latitude for the power plant, fuel source of the power plant, estimated generation power (in some years) (estimated_generation_gwh_2017)

# %% [markdown]
# Importing GeoJSON data

# %%
import requests

geo = requests.get(
    "https://r2.datahub.io/clvyjaryy0000la0cxieg4o8o/main/raw/data/countries.geojson"
)
shapes = geo.json()
print("loaded")
# Out:
# loaded

# %% [markdown]
# we wll use ISO3166-1-Alpha-3 key to match with the power plant data

# %%
def plot_pw(df):
    """This function makes a chloropleth map of NYC, using a DataFrame with a boro_cd and a requests_per_capita column."""

    fig = px.choropleth_map(
        df,
        locations="country",  # column name to match on
        color="capacity_mw",  # column name for values
        geojson=shapes,
        featureidkey="properties.ISO3166-1-Alpha-3",  # GeoJSON property to match on
        center={"lat": 40.71, "lon": -73.98},
        zoom=9,
        height=600,
        title="Requests per capita across Community Districts",
    )

    fig.show()
